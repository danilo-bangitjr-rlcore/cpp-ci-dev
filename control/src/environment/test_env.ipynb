# %%
from opc_connection import OpcConnection
from InfluxOPCEnv import InfluxOPCEnv, DBClientWrapper
from ReseauEnv import date_to_timestamp_reseau

import json

# %%
db_settings_pth = "/Users/revanmacqueen/RL-Core/root/control/src/environment/reseau/db_settings_local.json"
db_settings = json.load(open(db_settings_pth, "r"))
opc_settings_pth = "/Users/revanmacqueen/RL-Core/root/control/src/environment/reseau/opc_settings_local.json"
opc_settings = json.load(open(opc_settings_pth, "r"))

# %%
db_client = DBClientWrapper(db_settings["bucket"], db_settings["org"], 
                            db_settings["token"], db_settings["url"], date_fn=date_to_timestamp_reseau)

# %%
opc_connection = OpcConnection(opc_settings["IP"], opc_settings["port"])

# %%
FPM_control_tag = "osoyoos.plc.Process_DB.P250 Flow Pace Calc.Flow Pace Multiplier"
data_folder = "/Users/revanmacqueen/RL-Core/root/control/src/environment/reseau/datalogs/"

date_col = "Date "
col_names = [" AIT101 NTU ",
            " AIT301 ppm ",
            " AIT401 NTU ",
            " FIT101 Lpm ",
            " FIT210 Lpm ",
            " FIT230 Lpm ",
            " FIT250 Lpm ",
            " FIT401 Lpm ", 
            " PT100 psi ", 
            " PT101 psi ", 
            " PT151 psi ", 
            " PT161 psi ", 
            " PT171 psi ", 
            " PT301 psi ", 
            " PT302 psi"]


env = InfluxOPCEnv(db_client, opc_connection, runtime=10, 
                   control_tags=['FPM_control_tag'], 
                   offline_data_folder=data_folder, date_col=date_col, col_names=col_names)

# %%
env.reset()
state, reward, done, _, _ = env.get_observations_since_time(0, 0)

# %%
await env.take_action(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 await env.take_action(0)
#
# File ~/RL-Core/root/control/src/environment/InfluxOPCEnv.py:117, in InfluxOPCEnv.take_action(self, a)
#     112 async def take_action(self, a):
#     113     # get the list of nodes
#     114     # remember these are simulated nodes for these
#     115     # write examples so we don't change real
#     116     # values on the PLC
# --> 117     nodes = await self.opc_connection.get_nodes(self.control_tags)
#     119     # get the variant types
#     120     # this is necessary to properly specify the
#     121     # data types for the actual write operation
#     122     variant_types = await self.opc_connection.read_variant_types(nodes)
#
# File ~/RL-Core/root/control/src/environment/opc_connection.py:46, in OpcConnection.get_nodes(self, addresses)
#      44 while True:
#      45     try:
# ---> 46         nodes = [
#      47             self.client.get_node(f"ns=2;s={address}") for address in addresses
#      48         ]
#      49         return nodes
#      50     except (ConnectionError, ua.UaError, TimeoutError):
#
# File ~/RL-Core/root/control/src/environment/opc_connection.py:47, in <listcomp>(.0)
#      44 while True:
#      45     try:
#      46         nodes = [
# ---> 47             self.client.get_node(f"ns=2;s={address}") for address in addresses
#      48         ]
#      49         return nodes
#      50     except (ConnectionError, ua.UaError, TimeoutError):
#
# AttributeError: 'OpcConnection' object has no attribute 'client'
