# %%
import torch

# %%
def nothing():
    return

# %%
ctx = torch.no_grad if False else nothing
with ctx():
    print('test')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ctx = torch.no_grad if False else nothing
# ----> 2 with ctx():
#       3     print('test')
#
# TypeError: 'NoneType' object does not support the context manager protocol

# %%
:
